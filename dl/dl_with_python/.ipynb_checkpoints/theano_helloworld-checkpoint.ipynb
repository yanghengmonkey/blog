# %%
# %matplotlib inline

# %%
import numpy as np

# %%
np.random.seed(123)

# %%
import matplotlib.pyplot as plt

# %%
import theano

# %%
from theano import tensor as T, function

# %%
from IPython import display

# %%
import time

# %% [markdown]
# ## A simple problem

# %%
np.random.seed(123)

noise_var = 0.5
n_samples = 1000

noise = np.random.normal(0,noise_var, n_samples)

#x0 = np.arange(n_samples)
#w,b=np.random.randn(2)
#y0 = w*x0+b
#plt.plot(x0,y0,'.')

x = np.arange(n_samples)
x = (x- x.mean())/x.std()
y = w*x+b
plt.plot(x,y,'-r')
y=y+noise
plt.plot(x,y,'.')

# %%
noise_var = .5 # noise variance, conrtrols how hard is the problem, the larger the harder
n_samples = 1000 # number of observations

n = np.random.normal(0, noise_var, n_samples)
x = np.arange(n_samples)
x = (x - x.mean()) / x.std() # always a good practice to standardize the input data
w, b = np.random.randn(2)

d = w*x + b # correct answer
y = d + n# noisy observations

# %%
plt.plot(x, y, '.')
plt.plot(x, d, '-r', linewidth=2.)
plt.legend(('noisy obesrvations', 'desired'))
plt.title('input-output map')
# Out:
# Text(0.5, 1.0, 'input-output map')

# %% [markdown]
# ## Theano model
